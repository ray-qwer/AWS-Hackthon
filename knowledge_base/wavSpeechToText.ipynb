# %%
# 1. 安裝必要的依賴庫
# 在Colab中執行以下命令來安裝所需套件
# !pip install -q transformers torchaudio
# !pip install -q git+https://github.com/openai/whisper.git

# 2. 導入必要的庫
import os
import json
import torch
import whisper
from google.colab import drive

# 3. 掛載Google Drive
# 掛載Drive以訪問WAV檔案
drive.mount('/content/drive')
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Mounted at /content/drive

# %%
# 4. 設置環境和參數
# 檢查是否有GPU可用
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# 設定輸入和輸出路徑
input_folder = "/content/drive/MyDrive/2025AWS/FEniX訓練資料/audio_segments"  # WAV檔案資料夾
output_folder = "/content/drive/MyDrive/2025AWS/FEniX_Text"  # 儲存轉錄結果的資料夾
os.makedirs(output_folder, exist_ok=True)
# Out:
# Using device: cuda

# %%
# 初始化Whisper模型
# 使用 'large-v3' 模型以獲得高準確度，根據需求可改為 'small' 或 'medium'
try:
    model = whisper.load_model("large-v3").to(device)
except Exception as e:
    print(f"Error loading Whisper model: {e}")
    raise
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [01:16<00:00, 40.3MiB/s]

# %%
# 5. 定義語音轉文字函數
def transcribe_audio(audio_path):
    """使用Whisper模型將WAV音頻轉為文字"""
    try:
        result = model.transcribe(audio_path, language="zh")  # 設為中文，根據需求可改
        return result["text"]
    except Exception as e:
        print(f"Error transcribing {audio_path}: {e}")
        return ""

# 6. 主處理邏輯
def process_wav_files(input_folder, output_folder):
    """處理所有WAV檔案並按講者分類轉錄"""
    transcriptions = {}  # 儲存所有講者的轉錄結果

    # 遍歷輸入資料夾中的所有WAV檔案
    for filename in os.listdir(input_folder):
        if filename.endswith(".wav"):
            # 提取講者ID（假設檔案名以SPEAKER_XX開頭）
            speaker_id = filename.split("_")[0]  # e.g., SPEAKER_00
            if speaker_id not in transcriptions:
                transcriptions[speaker_id] = []

            # 設定路徑
            wav_path = os.path.join(input_folder, filename)
            print(f"Processing {filename}...")

            # 轉錄音頻
            text = transcribe_audio(wav_path)
            if text:
                transcriptions[speaker_id].append({
                    "filename": filename,
                    "text": text
                })

    # 儲存轉錄結果到JSON檔案
    output_json = os.path.join(output_folder, "transcriptions.json")
    with open(output_json, "w", encoding="utf-8") as f:
        json.dump(transcriptions, f, ensure_ascii=False, indent=4)
    print(f"Transcriptions saved to {output_json}")

# %%
# 7. 執行處理
if __name__ == "__main__":
    # 確保輸入資料夾存在
    if not os.path.exists(input_folder):
        print(f"Input folder {input_folder} does not exist. Please check the path.")
    else:
        process_wav_files(input_folder, output_folder)
# Out:
# Processing SPEAKER_01_0-1.wav...
# Processing SPEAKER_00_7-7.wav...
# Processing SPEAKER_01_7-11.wav...
# Processing SPEAKER_00_8-12.wav...
# Processing SPEAKER_01_14-14.wav...
# Processing SPEAKER_00_13-15.wav...
# Processing SPEAKER_03_15-19.wav...
# Processing SPEAKER_00_20-27.wav...
# Processing SPEAKER_01_19-19.wav...
# Processing SPEAKER_01_27-28.wav...
# Processing SPEAKER_02_17-19.wav...
# Processing SPEAKER_01_29-30.wav...
# Processing SPEAKER_00_28-30.wav...
# Processing SPEAKER_00_30-44.wav...
# Processing SPEAKER_00_44-45.wav...
# Processing SPEAKER_00_45-60.wav...
# Processing SPEAKER_01_46-46.wav...
# Processing SPEAKER_01_60-65.wav...
# Processing SPEAKER_01_67-72.wav...
# Processing SPEAKER_00_66-67.wav...
# Processing SPEAKER_00_67-67.wav...
# Processing SPEAKER_01_74-74.wav...
# Processing SPEAKER_01_78-78.wav...
# Processing SPEAKER_03_77-78.wav...
# Processing SPEAKER_01_80-88.wav...
# Processing SPEAKER_00_85-86.wav...
# Processing SPEAKER_02_78-80.wav...
# Processing SPEAKER_02_85-85.wav...
# Processing SPEAKER_00_88-90.wav...
# Processing SPEAKER_01_90-90.wav...
# Processing SPEAKER_00_95-104.wav...
# Processing SPEAKER_01_90-96.wav...
# Processing SPEAKER_01_97-98.wav...
# Processing SPEAKER_01_101-102.wav...
# Processing SPEAKER_00_105-106.wav...
# Processing SPEAKER_02_105-112.wav...
# Processing SPEAKER_00_106-109.wav...
# Processing SPEAKER_00_110-110.wav...
# Processing SPEAKER_01_110-110.wav...
# Processing SPEAKER_00_119-120.wav...
# Processing SPEAKER_02_113-121.wav...
# Processing SPEAKER_00_112-113.wav...
# Processing SPEAKER_00_110-112.wav...
# Processing SPEAKER_01_121-125.wav...
# Processing SPEAKER_02_123-125.wav...
# Processing SPEAKER_02_125-126.wav...
# Processing SPEAKER_01_126-132.wav...
# Processing SPEAKER_00_136-136.wav...
# Processing SPEAKER_02_129-133.wav...
# Processing SPEAKER_00_132-136.wav...
# Processing SPEAKER_00_139-139.wav...
# Processing SPEAKER_00_137-137.wav...
# Processing SPEAKER_01_136-148.wav...
# Processing SPEAKER_02_143-144.wav...
# Processing SPEAKER_02_139-142.wav...
# Processing SPEAKER_02_146-151.wav...
# Processing SPEAKER_00_144-144.wav...
# Processing SPEAKER_02_144-144.wav...
# Processing SPEAKER_02_144-145.wav...
# Processing SPEAKER_01_149-150.wav...
# Processing SPEAKER_01_151-151.wav...
# Processing SPEAKER_01_152-156.wav...
# Processing SPEAKER_00_155-155.wav...
# Processing SPEAKER_00_153-154.wav...
# Processing SPEAKER_00_165-165.wav...
# Processing SPEAKER_00_156-165.wav...
# Processing SPEAKER_02_165-166.wav...
# Processing SPEAKER_02_166-166.wav...
# Processing SPEAKER_00_166-166.wav...
# Processing SPEAKER_01_166-168.wav...
# Processing SPEAKER_02_168-169.wav...
# Processing SPEAKER_00_168-174.wav...
# Processing SPEAKER_01_174-175.wav...
# Processing SPEAKER_01_178-179.wav...
# Processing SPEAKER_01_169-169.wav...
# Processing SPEAKER_02_171-181.wav...
# Processing SPEAKER_01_179-181.wav...
# Processing SPEAKER_01_181-181.wav...
# Processing SPEAKER_00_181-182.wav...
# Processing SPEAKER_00_182-186.wav...
# Processing SPEAKER_01_182-182.wav...
# Processing SPEAKER_01_183-184.wav...
# Processing SPEAKER_01_182-183.wav...
# Processing SPEAKER_01_186-196.wav...
# Processing SPEAKER_00_191-192.wav...
# Processing SPEAKER_00_194-196.wav...
# Processing SPEAKER_00_196-196.wav...
# Processing SPEAKER_02_210-210.wav...
# Processing SPEAKER_00_203-205.wav...
# Processing SPEAKER_01_196-210.wav...
# Processing SPEAKER_03_210-211.wav...
# Processing SPEAKER_02_211-211.wav...
# Processing SPEAKER_01_211-212.wav...
# Processing SPEAKER_00_211-212.wav...
# Processing SPEAKER_00_212-212.wav...
# Processing SPEAKER_00_213-215.wav...
# Processing SPEAKER_01_214-219.wav...
# Processing SPEAKER_01_221-221.wav...
# Processing SPEAKER_00_217-218.wav...
# Processing SPEAKER_00_219-221.wav...
# Processing SPEAKER_00_221-224.wav...
# Processing SPEAKER_01_222-224.wav...
# Processing SPEAKER_01_224-224.wav...
# Processing SPEAKER_01_224-225.wav...
# Processing SPEAKER_00_226-226.wav...
# Processing SPEAKER_00_225-225.wav...
# Processing SPEAKER_01_225-226.wav...
# Processing SPEAKER_01_226-231.wav...
# Processing SPEAKER_02_231-240.wav...
# Processing SPEAKER_01_231-232.wav...
# Processing SPEAKER_00_237-237.wav...
# Processing SPEAKER_01_236-237.wav...
# Processing SPEAKER_03_237-237.wav...
# Processing SPEAKER_00_237-238.wav...
# Processing SPEAKER_03_238-241.wav...
# Processing SPEAKER_03_241-242.wav...
# Processing SPEAKER_01_242-242.wav...
# Processing SPEAKER_03_243-245.wav...
# Processing SPEAKER_01_242-243.wav...
# Processing SPEAKER_00_247-247.wav...
# Processing SPEAKER_03_247-247.wav...
# Processing SPEAKER_00_245-247.wav...
# Processing SPEAKER_01_247-247.wav...
# Processing SPEAKER_00_247-248.wav...
# Processing SPEAKER_03_247-251.wav...
# Processing SPEAKER_01_248-248.wav...
# Processing SPEAKER_03_252-252.wav...
# Processing SPEAKER_02_248-248.wav...
# Processing SPEAKER_00_253-254.wav...
# Processing SPEAKER_02_250-255.wav...
# Processing SPEAKER_00_254-256.wav...
# Processing SPEAKER_03_254-254.wav...
# Processing SPEAKER_00_254-254.wav...
# Processing SPEAKER_01_255-256.wav...
# Processing SPEAKER_01_256-256.wav...
# Processing SPEAKER_00_256-263.wav...
# Processing SPEAKER_03_260-261.wav...
# Processing SPEAKER_03_262-266.wav...
# Processing SPEAKER_01_265-265.wav...
# Processing SPEAKER_02_263-263.wav...
# Processing SPEAKER_02_265-265.wav...
# Processing SPEAKER_03_267-271.wav...
# Processing SPEAKER_00_268-271.wav...
# Processing SPEAKER_01_272-278.wav...
# Processing SPEAKER_00_271-272.wav...
# Processing SPEAKER_01_271-271.wav...
# Processing SPEAKER_01_278-278.wav...
# Processing SPEAKER_00_278-284.wav...
# Processing SPEAKER_00_276-277.wav...
# Processing SPEAKER_01_278-284.wav...
# Processing SPEAKER_00_284-284.wav...
# Processing SPEAKER_01_284-286.wav...
# Processing SPEAKER_00_285-286.wav...
# Processing SPEAKER_00_290-290.wav...
# Processing SPEAKER_01_286-290.wav...
# Processing SPEAKER_01_292-292.wav...
# Processing SPEAKER_00_291-291.wav...
# Processing SPEAKER_02_290-290.wav...
# Processing SPEAKER_03_294-301.wav...
# Processing SPEAKER_01_292-293.wav...
# Processing SPEAKER_03_293-293.wav...
# Processing SPEAKER_00_301-302.wav...
# Processing SPEAKER_00_302-316.wav...
# Processing SPEAKER_02_313-314.wav...
# Processing SPEAKER_01_306-311.wav...
# Processing SPEAKER_01_303-303.wav...
# Processing SPEAKER_03_316-316.wav...
# Processing SPEAKER_00_316-316.wav...
# Processing SPEAKER_01_319-326.wav...
# Processing SPEAKER_00_320-324.wav...
# Processing SPEAKER_00_316-318.wav...
# Processing SPEAKER_00_325-331.wav...
# Processing SPEAKER_01_329-331.wav...
# Processing SPEAKER_00_331-338.wav...
# Processing SPEAKER_01_331-333.wav...
# Processing SPEAKER_01_336-336.wav...
# Processing SPEAKER_00_338-338.wav...
# Processing SPEAKER_01_338-338.wav...
# Processing SPEAKER_01_338-342.wav...
# Processing SPEAKER_00_340-341.wav...
# Processing SPEAKER_00_345-346.wav...
# Processing SPEAKER_01_342-347.wav...
# Processing SPEAKER_02_347-347.wav...
# Processing SPEAKER_01_347-349.wav...
# Processing SPEAKER_00_350-355.wav...
# Processing SPEAKER_00_347-348.wav...
# Processing SPEAKER_00_355-355.wav...
# Processing SPEAKER_01_355-357.wav...
# Processing SPEAKER_01_350-351.wav...
# Processing SPEAKER_00_359-360.wav...
# Processing SPEAKER_00_360-361.wav...
# Processing SPEAKER_01_357-359.wav...
# Processing SPEAKER_03_362-363.wav...
# Processing SPEAKER_01_363-363.wav...
# Processing SPEAKER_03_364-365.wav...
# Processing SPEAKER_03_363-364.wav...
# Processing SPEAKER_01_364-364.wav...
# Processing SPEAKER_02_365-368.wav...
# Processing SPEAKER_01_365-377.wav...
# Processing SPEAKER_02_372-372.wav...
# Processing SPEAKER_00_376-377.wav...
# Processing SPEAKER_03_372-376.wav...
# Processing SPEAKER_02_377-378.wav...
# Processing SPEAKER_02_378-385.wav...
# Processing SPEAKER_01_379-379.wav...
# Processing SPEAKER_01_385-393.wav...
# Processing SPEAKER_02_385-385.wav...
# Processing SPEAKER_01_382-383.wav...
# Processing SPEAKER_02_385-386.wav...
# Processing SPEAKER_02_388-392.wav...
# Processing SPEAKER_00_392-393.wav...
# Processing SPEAKER_02_392-396.wav...
# Processing SPEAKER_01_392-400.wav...
# Processing SPEAKER_02_397-397.wav...
# Processing SPEAKER_00_397-397.wav...
# Processing SPEAKER_02_396-397.wav...
# Processing SPEAKER_00_404-407.wav...
# Processing SPEAKER_01_401-406.wav...
# Processing SPEAKER_00_401-403.wav...
# Processing SPEAKER_00_408-409.wav...
# Processing SPEAKER_01_408-411.wav...
# Processing SPEAKER_02_407-407.wav...
# Processing SPEAKER_02_411-415.wav...
# Processing SPEAKER_00_411-417.wav...
# Processing SPEAKER_01_415-415.wav...
# Processing SPEAKER_02_416-420.wav...
# Processing SPEAKER_00_419-421.wav...
# Processing SPEAKER_02_421-422.wav...
# Processing SPEAKER_00_421-422.wav...
# Processing SPEAKER_02_422-422.wav...
# Processing SPEAKER_00_422-425.wav...
# Processing SPEAKER_02_423-423.wav...
# Processing SPEAKER_00_426-426.wav...
# Processing SPEAKER_02_424-424.wav...
# Processing SPEAKER_02_425-437.wav...
# Processing SPEAKER_03_433-433.wav...
# Processing SPEAKER_01_432-433.wav...
# Processing SPEAKER_00_430-432.wav...
# Processing SPEAKER_03_437-437.wav...
# Processing SPEAKER_01_433-437.wav...
# Processing SPEAKER_02_437-437.wav...
# Processing SPEAKER_02_441-442.wav...
# Processing SPEAKER_00_437-443.wav...
# Processing SPEAKER_01_442-442.wav...
# Processing SPEAKER_02_442-442.wav...
# Processing SPEAKER_02_443-443.wav...
# Processing SPEAKER_00_444-444.wav...
# Processing SPEAKER_02_444-445.wav...
# Processing SPEAKER_01_445-445.wav...
# Processing SPEAKER_02_445-445.wav...
# Processing SPEAKER_01_445-446.wav...
# Processing SPEAKER_01_446-446.wav...
# Processing SPEAKER_01_446-447.wav...
# Processing SPEAKER_01_448-451.wav...
# Processing SPEAKER_02_446-446.wav...
# Processing SPEAKER_01_451-452.wav...
# Processing SPEAKER_00_452-452.wav...
# Processing SPEAKER_01_452-453.wav...
# Processing SPEAKER_00_453-454.wav...
# Processing SPEAKER_01_453-456.wav...
# Processing SPEAKER_00_453-453.wav...
# Processing SPEAKER_01_457-457.wav...
# Processing SPEAKER_01_458-465.wav...
# Processing SPEAKER_00_461-462.wav...
# Processing SPEAKER_02_462-463.wav...
# Processing SPEAKER_00_463-463.wav...
# Processing SPEAKER_00_465-467.wav...
# Processing SPEAKER_02_466-467.wav...
# Processing SPEAKER_01_465-466.wav...
# Processing SPEAKER_02_467-468.wav...
# Processing SPEAKER_00_467-471.wav...
# Processing SPEAKER_01_472-474.wav...
# Processing SPEAKER_02_469-475.wav...
# Processing SPEAKER_01_474-474.wav...
# Processing SPEAKER_01_475-477.wav...
# Processing SPEAKER_01_478-478.wav...
# Processing SPEAKER_02_478-479.wav...
# Processing SPEAKER_01_481-482.wav...
# Processing SPEAKER_01_478-481.wav...
# Processing SPEAKER_01_482-483.wav...
# Processing SPEAKER_01_484-489.wav...
# Processing SPEAKER_00_483-483.wav...
# Processing SPEAKER_00_490-497.wav...
# Processing SPEAKER_00_484-485.wav...
# Processing SPEAKER_01_494-497.wav...
# Processing SPEAKER_01_500-501.wav...
# Processing SPEAKER_02_497-505.wav...
# Processing SPEAKER_02_506-509.wav...
# Processing SPEAKER_01_507-508.wav...
# Processing SPEAKER_00_507-507.wav...
# Processing SPEAKER_00_509-512.wav...
# Processing SPEAKER_00_508-508.wav...
# Processing SPEAKER_02_509-509.wav...
# Processing SPEAKER_02_511-512.wav...
# Processing SPEAKER_01_512-513.wav...
# Processing SPEAKER_02_513-519.wav...
# Processing SPEAKER_02_512-513.wav...
# Processing SPEAKER_00_518-518.wav...
# Processing SPEAKER_00_518-519.wav...
# Processing SPEAKER_01_518-518.wav...
# Processing SPEAKER_00_519-520.wav...
# Processing SPEAKER_01_519-521.wav...
# Processing SPEAKER_00_522-522.wav...
# Processing SPEAKER_00_522-527.wav...
# Processing SPEAKER_02_522-522.wav...
# Processing SPEAKER_01_523-525.wav...
# Processing SPEAKER_01_525-525.wav...
# Processing SPEAKER_01_531-533.wav...
# Processing SPEAKER_02_527-540.wav...
# Processing SPEAKER_00_533-534.wav...
# Processing SPEAKER_01_533-533.wav...
# Processing SPEAKER_00_533-533.wav...
# Processing SPEAKER_01_534-535.wav...
# Processing SPEAKER_01_534-534.wav...
# Processing SPEAKER_00_539-542.wav...
# Processing SPEAKER_01_535-535.wav...
# Processing SPEAKER_00_535-535.wav...
# Processing SPEAKER_02_541-541.wav...
# Processing SPEAKER_01_543-544.wav...
# Processing SPEAKER_00_542-546.wav...
# Processing SPEAKER_01_546-546.wav...
# Processing SPEAKER_01_546-549.wav...
# Processing SPEAKER_00_549-550.wav...
# Processing SPEAKER_00_550-553.wav...
# Processing SPEAKER_01_552-554.wav...
# Processing SPEAKER_01_554-557.wav...
# Processing SPEAKER_01_557-557.wav...
# Processing SPEAKER_00_557-557.wav...
# Processing SPEAKER_00_557-558.wav...
# Processing SPEAKER_00_559-559.wav...
# Processing SPEAKER_02_558-561.wav...
# Processing SPEAKER_00_561-563.wav...
# Processing SPEAKER_00_563-565.wav...
# Processing SPEAKER_00_565-566.wav...
# Processing SPEAKER_00_567-568.wav...
# Processing SPEAKER_03_572-572.wav...
# Processing SPEAKER_01_569-572.wav...
# Processing SPEAKER_00_572-573.wav...
# Processing SPEAKER_01_573-573.wav...
# Processing SPEAKER_00_573-579.wav...
# Processing SPEAKER_01_574-574.wav...
# Processing SPEAKER_01_581-583.wav...
# Processing SPEAKER_00_579-582.wav...
# Processing SPEAKER_00_583-587.wav...
# Processing SPEAKER_03_588-590.wav...
# Processing SPEAKER_03_590-595.wav...
# Processing SPEAKER_03_595-599.wav...
# Processing SPEAKER_00_595-596.wav...
# Processing SPEAKER_03_600-600.wav...
# Processing SPEAKER_01_600-602.wav...
# Processing SPEAKER_03_599-599.wav...
# Processing SPEAKER_03_601-601.wav...
# Processing SPEAKER_00_601-601.wav...
# Processing SPEAKER_02_602-603.wav...
# Processing SPEAKER_03_601-603.wav...
# Processing SPEAKER_00_603-603.wav...
# Processing SPEAKER_02_603-610.wav...
# Processing SPEAKER_01_605-609.wav...
# Processing SPEAKER_00_604-604.wav...
# Processing SPEAKER_00_609-609.wav...
# Processing SPEAKER_00_610-610.wav...
# Processing SPEAKER_01_610-610.wav...
# Processing SPEAKER_02_610-617.wav...
# Processing SPEAKER_00_611-611.wav...
# Processing SPEAKER_01_611-611.wav...
# Processing SPEAKER_00_615-615.wav...
# Processing SPEAKER_00_617-618.wav...
# Processing SPEAKER_02_617-618.wav...
# Processing SPEAKER_02_620-621.wav...
# Processing SPEAKER_02_618-620.wav...
# Processing SPEAKER_02_624-624.wav...
# Processing SPEAKER_02_622-623.wav...
# Processing SPEAKER_02_624-628.wav...
# Processing SPEAKER_01_624-624.wav...
# Processing SPEAKER_00_624-624.wav...
# Processing SPEAKER_02_629-633.wav...
# Processing SPEAKER_00_628-628.wav...
# Processing SPEAKER_00_629-629.wav...
# Processing SPEAKER_02_633-633.wav...
# Processing SPEAKER_01_636-637.wav...
# Processing SPEAKER_02_634-649.wav...
# Processing SPEAKER_00_638-638.wav...
# Processing SPEAKER_01_641-642.wav...
# Processing SPEAKER_01_638-638.wav...
# Processing SPEAKER_00_648-651.wav...
# Processing SPEAKER_03_649-649.wav...
# Processing SPEAKER_02_657-657.wav...
# Processing SPEAKER_00_652-658.wav...
# Processing SPEAKER_01_657-657.wav...
# Processing SPEAKER_00_658-663.wav...
# Processing SPEAKER_02_660-662.wav...
# Processing SPEAKER_04_662-662.wav...
# Processing SPEAKER_01_663-671.wav...
# Processing SPEAKER_00_668-669.wav...
# Processing SPEAKER_02_672-672.wav...
# Processing SPEAKER_00_670-671.wav...
# Processing SPEAKER_01_672-672.wav...
# Processing SPEAKER_00_672-672.wav...
# Processing SPEAKER_00_677-678.wav...
# Processing SPEAKER_00_673-674.wav...
# Processing SPEAKER_00_674-677.wav...
# Processing SPEAKER_02_678-691.wav...
# Processing SPEAKER_01_680-681.wav...
# Processing SPEAKER_00_685-685.wav...
# Processing SPEAKER_01_685-686.wav...
# Processing SPEAKER_01_687-688.wav...
# Processing SPEAKER_00_690-690.wav...
# Processing SPEAKER_00_691-691.wav...
# Processing SPEAKER_02_691-691.wav...
# Processing SPEAKER_00_692-693.wav...
# Processing SPEAKER_00_691-692.wav...
# Processing SPEAKER_02_692-692.wav...
# Processing SPEAKER_02_693-693.wav...
# Processing SPEAKER_00_694-694.wav...
# Processing SPEAKER_01_693-697.wav...
# Processing SPEAKER_01_697-699.wav...
# Processing SPEAKER_00_702-702.wav...
# Processing SPEAKER_01_700-708.wav...
# Processing SPEAKER_02_707-708.wav...
# Processing SPEAKER_01_715-716.wav...
# Processing SPEAKER_02_708-723.wav...
# Processing SPEAKER_01_716-717.wav...
# Processing SPEAKER_00_716-716.wav...
# Processing SPEAKER_01_718-718.wav...
# Processing SPEAKER_01_719-719.wav...
# Processing SPEAKER_00_718-719.wav...
# Processing SPEAKER_00_719-719.wav...
# Processing SPEAKER_00_720-721.wav...
# Processing SPEAKER_01_721-721.wav...
# Processing SPEAKER_00_721-722.wav...
# Processing SPEAKER_00_721-721.wav...
# Processing SPEAKER_01_723-735.wav...
# Processing SPEAKER_00_727-729.wav...
# Processing SPEAKER_02_733-733.wav...
# Processing SPEAKER_01_735-735.wav...
# Processing SPEAKER_02_738-738.wav...
# Processing SPEAKER_02_735-737.wav...
# Processing SPEAKER_01_737-738.wav...
# Processing SPEAKER_00_738-738.wav...
# Processing SPEAKER_01_741-745.wav...
# Processing SPEAKER_00_741-741.wav...
# Processing SPEAKER_01_738-740.wav...
# Processing SPEAKER_00_744-746.wav...
# Processing SPEAKER_01_745-747.wav...
# Processing SPEAKER_01_747-748.wav...
# Processing SPEAKER_00_747-747.wav...
# Processing SPEAKER_02_751-753.wav...
# Processing SPEAKER_00_748-751.wav...
# Processing SPEAKER_02_748-748.wav...
# Processing SPEAKER_00_752-752.wav...
# Processing SPEAKER_00_753-754.wav...
# Processing SPEAKER_02_753-754.wav...
# Processing SPEAKER_02_757-757.wav...
# Processing SPEAKER_02_754-754.wav...
# Processing SPEAKER_01_754-755.wav...
# Processing SPEAKER_01_757-758.wav...
# Processing SPEAKER_02_758-758.wav...
# Processing SPEAKER_01_758-758.wav...
# Processing SPEAKER_01_758-768.wav...
# Processing SPEAKER_02_759-759.wav...
# Processing SPEAKER_00_759-760.wav...
# Processing SPEAKER_00_760-760.wav...
# Processing SPEAKER_02_760-760.wav...
# Processing SPEAKER_00_768-774.wav...
# Processing SPEAKER_00_774-775.wav...
# Processing SPEAKER_01_774-782.wav...
# Processing SPEAKER_00_780-780.wav...
# Processing SPEAKER_00_776-776.wav...
# Processing SPEAKER_00_776-779.wav...
# Processing SPEAKER_01_784-785.wav...
# Processing SPEAKER_00_783-798.wav...
# Processing SPEAKER_01_787-787.wav...
# Processing SPEAKER_01_789-789.wav...
# Processing SPEAKER_02_789-789.wav...
# Processing SPEAKER_01_798-799.wav...
# Processing SPEAKER_01_799-808.wav...
# Processing SPEAKER_02_800-800.wav...
# Processing SPEAKER_00_800-800.wav...
# Processing SPEAKER_00_806-806.wav...
# Processing SPEAKER_00_807-807.wav...
# Processing SPEAKER_01_811-814.wav...
# Processing SPEAKER_01_810-811.wav...
# Processing SPEAKER_00_808-812.wav...
# Processing SPEAKER_02_813-815.wav...
# Processing SPEAKER_02_816-819.wav...
# Processing SPEAKER_01_815-816.wav...
# Processing SPEAKER_03_816-816.wav...
# Processing SPEAKER_01_816-816.wav...
# Processing SPEAKER_02_819-819.wav...
# Processing SPEAKER_02_820-823.wav...
# Processing SPEAKER_03_820-820.wav...
# Processing SPEAKER_01_820-820.wav...
# Processing SPEAKER_02_823-823.wav...
# Processing SPEAKER_03_824-824.wav...
# Processing SPEAKER_01_824-824.wav...
# Processing SPEAKER_02_824-829.wav...
# Processing SPEAKER_00_825-825.wav...
# Processing SPEAKER_03_824-825.wav...
# Processing SPEAKER_03_826-827.wav...
# Processing SPEAKER_01_825-826.wav...
# Processing SPEAKER_03_825-825.wav...
# Processing SPEAKER_00_829-829.wav...
# Processing SPEAKER_00_831-835.wav...
# Processing SPEAKER_01_834-838.wav...
# Processing SPEAKER_00_836-844.wav...
# Processing SPEAKER_01_842-844.wav...
# Processing SPEAKER_00_844-846.wav...
# Processing SPEAKER_01_848-849.wav...
# Processing SPEAKER_02_847-851.wav...
# Processing SPEAKER_01_850-851.wav...
# Processing SPEAKER_00_851-851.wav...
# Processing SPEAKER_01_851-851.wav...
# Processing SPEAKER_02_852-852.wav...
# Processing SPEAKER_00_852-859.wav...
# Processing SPEAKER_01_858-859.wav...
# Processing SPEAKER_01_852-852.wav...
# Processing SPEAKER_00_859-861.wav...
# Processing SPEAKER_01_867-868.wav...
# Processing SPEAKER_02_859-873.wav...
# Processing SPEAKER_01_870-871.wav...
# Processing SPEAKER_02_873-874.wav...
# Processing SPEAKER_03_871-871.wav...
# Processing SPEAKER_03_874-874.wav...
# Processing SPEAKER_01_874-874.wav...
# Processing SPEAKER_00_874-876.wav...
# Processing SPEAKER_00_879-879.wav...
# Processing SPEAKER_00_877-878.wav...
# Processing SPEAKER_01_877-879.wav...
# Processing SPEAKER_00_880-885.wav...
# Processing SPEAKER_01_880-882.wav...
# Processing SPEAKER_01_884-884.wav...
# Processing SPEAKER_00_885-885.wav...
# Processing SPEAKER_01_885-886.wav...
# Processing SPEAKER_02_886-886.wav...
# Processing SPEAKER_00_886-888.wav...
# Processing SPEAKER_00_889-889.wav...
# Processing SPEAKER_02_889-889.wav...
# Processing SPEAKER_01_889-890.wav...
# Processing SPEAKER_00_892-892.wav...
# Processing SPEAKER_01_891-892.wav...
# Processing SPEAKER_01_893-904.wav...
# Processing SPEAKER_01_892-892.wav...
# Processing SPEAKER_02_896-897.wav...
# Processing SPEAKER_03_900-900.wav...
# Processing SPEAKER_02_900-900.wav...
# Processing SPEAKER_03_901-904.wav...
# Processing SPEAKER_02_900-901.wav...
# Processing SPEAKER_01_904-909.wav...
# Processing SPEAKER_05_904-904.wav...
# Processing SPEAKER_00_906-906.wav...
# Processing SPEAKER_02_906-906.wav...
# Processing SPEAKER_00_908-908.wav...
# Processing SPEAKER_00_909-911.wav...
# Processing SPEAKER_04_908-908.wav...
# Processing SPEAKER_01_910-910.wav...
# Processing SPEAKER_01_909-910.wav...
# Processing SPEAKER_00_911-913.wav...
# Processing SPEAKER_00_913-919.wav...
# Processing SPEAKER_01_913-914.wav...
# Processing SPEAKER_01_917-917.wav...
# Processing SPEAKER_03_916-917.wav...
# Processing SPEAKER_03_919-920.wav...
# Processing SPEAKER_01_920-931.wav...
# Processing SPEAKER_00_926-926.wav...
# Processing SPEAKER_02_920-922.wav...
# Processing SPEAKER_00_922-922.wav...
# Processing SPEAKER_00_928-934.wav...
# Processing SPEAKER_01_932-934.wav...
# Processing SPEAKER_01_935-936.wav...
# Processing SPEAKER_00_934-940.wav...
# Processing SPEAKER_01_936-937.wav...
# Processing SPEAKER_01_937-937.wav...
# Processing SPEAKER_01_938-939.wav...
# Processing SPEAKER_01_938-938.wav...
# Processing SPEAKER_01_940-941.wav...
# Processing SPEAKER_00_940-944.wav...
# Processing SPEAKER_01_944-944.wav...
# Processing SPEAKER_01_943-944.wav...
# Processing SPEAKER_01_942-942.wav...
# Processing SPEAKER_01_944-945.wav...
# Processing SPEAKER_01_945-945.wav...
# Processing SPEAKER_00_945-945.wav...
# Processing SPEAKER_00_945-946.wav...
# Processing SPEAKER_01_945-946.wav...
# Processing SPEAKER_01_948-949.wav...
# Processing SPEAKER_00_947-948.wav...
# Processing SPEAKER_01_946-948.wav...
# Processing SPEAKER_00_949-954.wav...
# Processing SPEAKER_02_950-950.wav...
# Processing SPEAKER_02_952-960.wav...
# Processing SPEAKER_01_958-964.wav...
# Processing SPEAKER_01_954-957.wav...
# Processing SPEAKER_02_963-964.wav...
# Processing SPEAKER_01_964-971.wav...
# Processing SPEAKER_02_971-972.wav...
# Processing SPEAKER_03_973-973.wav...
# Processing SPEAKER_03_972-972.wav...
# Processing SPEAKER_01_974-974.wav...
# Processing SPEAKER_00_974-975.wav...
# Processing SPEAKER_02_973-979.wav...
# Processing SPEAKER_02_979-979.wav...
# Processing SPEAKER_01_979-991.wav...
# Processing SPEAKER_00_980-980.wav...
# Processing SPEAKER_00_987-990.wav...
# Processing SPEAKER_02_990-990.wav...
# Processing SPEAKER_02_991-992.wav...
# Processing SPEAKER_01_992-992.wav...
# Processing SPEAKER_02_992-992.wav...
# Processing SPEAKER_01_992-994.wav...
# Processing SPEAKER_02_994-995.wav...
# Processing SPEAKER_01_994-995.wav...
# Processing SPEAKER_01_995-998.wav...
# Processing SPEAKER_00_995-996.wav...
# Processing SPEAKER_00_996-996.wav...
# Processing SPEAKER_02_996-996.wav...
# Processing SPEAKER_02_997-1002.wav...
# Processing SPEAKER_00_998-998.wav...
# Processing SPEAKER_00_1000-1000.wav...
# Processing SPEAKER_01_999-1000.wav...
# Processing SPEAKER_00_1004-1009.wav...
# Processing SPEAKER_02_1005-1009.wav...
# Processing SPEAKER_02_1009-1009.wav...
# Processing SPEAKER_00_1009-1010.wav...
# Processing SPEAKER_00_1010-1012.wav...
# Processing SPEAKER_01_1011-1015.wav...
# Processing SPEAKER_01_1009-1010.wav...
# Processing SPEAKER_00_1014-1019.wav...
# Processing SPEAKER_01_1017-1018.wav...
# Processing SPEAKER_01_1019-1020.wav...
# Processing SPEAKER_03_1020-1020.wav...
# Processing SPEAKER_02_1020-1021.wav...
# Processing SPEAKER_02_1020-1020.wav...
# Processing SPEAKER_03_1021-1021.wav...
# Processing SPEAKER_02_1021-1022.wav...
# Processing SPEAKER_03_1023-1024.wav...
# Processing SPEAKER_02_1024-1024.wav...
# Processing SPEAKER_03_1021-1023.wav...
# Processing SPEAKER_01_1024-1026.wav...
# Processing SPEAKER_00_1026-1026.wav...
# Processing SPEAKER_01_1026-1027.wav...
# Processing SPEAKER_00_1027-1027.wav...
# Processing SPEAKER_00_1031-1037.wav...
# Processing SPEAKER_01_1029-1034.wav...
# Processing SPEAKER_01_1027-1029.wav...
# Processing SPEAKER_01_1034-1035.wav...
# Processing SPEAKER_01_1036-1036.wav...
# Processing SPEAKER_01_1036-1040.wav...
# Processing SPEAKER_00_1039-1040.wav...
# Processing SPEAKER_02_1039-1050.wav...
# Processing SPEAKER_00_1042-1044.wav...
# Processing SPEAKER_01_1051-1051.wav...
# Processing SPEAKER_03_1052-1055.wav...
# Processing SPEAKER_02_1052-1055.wav...
# Processing SPEAKER_02_1055-1056.wav...
# Processing SPEAKER_00_1056-1056.wav...
# Processing SPEAKER_02_1057-1060.wav...
# Processing SPEAKER_02_1061-1063.wav...
# Processing SPEAKER_00_1060-1061.wav...
# Processing SPEAKER_00_1061-1061.wav...
# Processing SPEAKER_00_1062-1065.wav...
# Processing SPEAKER_00_1061-1062.wav...
# Processing SPEAKER_02_1066-1070.wav...
# Processing SPEAKER_02_1064-1065.wav...
# Processing SPEAKER_01_1067-1070.wav...
# Processing SPEAKER_03_1070-1071.wav...
# Processing SPEAKER_02_1071-1071.wav...
# Processing SPEAKER_00_1070-1071.wav...
# Processing SPEAKER_00_1072-1072.wav...
# Processing SPEAKER_03_1071-1072.wav...
# Processing SPEAKER_02_1072-1073.wav...
# Processing SPEAKER_02_1074-1075.wav...
# Processing SPEAKER_02_1074-1074.wav...
# Processing SPEAKER_01_1075-1075.wav...
# Processing SPEAKER_03_1075-1075.wav...
# Processing SPEAKER_00_1075-1081.wav...
# Processing SPEAKER_01_1075-1077.wav...
# Processing SPEAKER_01_1078-1085.wav...
# Processing SPEAKER_00_1082-1083.wav...
# Processing SPEAKER_02_1085-1086.wav...
# Processing SPEAKER_01_1085-1085.wav...
# Processing SPEAKER_01_1085-1086.wav...
# Processing SPEAKER_02_1086-1089.wav...
# Processing SPEAKER_00_1086-1086.wav...
# Processing SPEAKER_01_1086-1087.wav...
# Processing SPEAKER_01_1087-1087.wav...
# Processing SPEAKER_00_1087-1087.wav...
# Processing SPEAKER_02_1089-1089.wav...
# Processing SPEAKER_00_1089-1089.wav...
# Processing SPEAKER_01_1089-1100.wav...
# Processing SPEAKER_02_1089-1090.wav...
# Processing SPEAKER_02_1094-1100.wav...
# Processing SPEAKER_02_1101-1101.wav...
# Processing SPEAKER_01_1100-1104.wav...
# Processing SPEAKER_00_1103-1108.wav...
# Processing SPEAKER_02_1104-1115.wav...
# Processing SPEAKER_00_1113-1114.wav...
# Processing SPEAKER_01_1115-1116.wav...
# Processing SPEAKER_00_1115-1130.wav...
# Processing SPEAKER_02_1121-1121.wav...
# Processing SPEAKER_01_1121-1123.wav...
# Processing SPEAKER_02_1125-1125.wav...
# Processing SPEAKER_01_1124-1125.wav...
# Processing SPEAKER_01_1123-1124.wav...
# Processing SPEAKER_03_1125-1126.wav...
# Processing SPEAKER_03_1125-1125.wav...
# Processing SPEAKER_01_1130-1134.wav...
# Processing SPEAKER_02_1130-1130.wav...
# Processing SPEAKER_02_1132-1143.wav...
# Processing SPEAKER_03_1142-1143.wav...
# Processing SPEAKER_03_1134-1134.wav...
# Processing SPEAKER_00_1143-1145.wav...
# Processing SPEAKER_01_1145-1151.wav...
# Processing SPEAKER_00_1150-1152.wav...
# Processing SPEAKER_01_1152-1152.wav...
# Processing SPEAKER_01_1152-1153.wav...
# Processing SPEAKER_00_1153-1160.wav...
# Processing SPEAKER_00_1160-1161.wav...
# Processing SPEAKER_00_1161-1169.wav...
# Processing SPEAKER_01_1175-1175.wav...
# Processing SPEAKER_00_1170-1175.wav...
# Processing SPEAKER_00_1175-1190.wav...
# Processing SPEAKER_01_1190-1190.wav...
# Processing SPEAKER_02_1190-1190.wav...
# Processing SPEAKER_00_1190-1191.wav...
# Processing SPEAKER_01_1191-1192.wav...
# Processing SPEAKER_00_1191-1193.wav...
# Processing SPEAKER_00_1194-1195.wav...
# Processing SPEAKER_00_1193-1194.wav...
# Processing SPEAKER_00_1198-1199.wav...
# Processing SPEAKER_00_1195-1197.wav...
# Processing SPEAKER_00_1202-1204.wav...
# Processing SPEAKER_00_1200-1202.wav...
# Processing SPEAKER_00_1204-1205.wav...
# Processing SPEAKER_00_1208-1209.wav...
# Processing SPEAKER_00_1205-1206.wav...
# Processing SPEAKER_02_1209-1209.wav...
# Processing SPEAKER_00_1209-1211.wav...
# Processing SPEAKER_01_1215-1219.wav...
# Processing SPEAKER_00_1211-1217.wav...
# Processing SPEAKER_00_1218-1220.wav...
# Processing SPEAKER_00_1220-1226.wav...
# Processing SPEAKER_01_1220-1223.wav...
# Processing SPEAKER_00_1228-1230.wav...
# Processing SPEAKER_01_1225-1235.wav...
# Processing SPEAKER_00_1233-1234.wav...
# Processing SPEAKER_00_1235-1250.wav...
# Processing SPEAKER_01_1239-1239.wav...
# Processing SPEAKER_01_1236-1238.wav...
# Processing SPEAKER_01_1245-1250.wav...
# Processing SPEAKER_02_1250-1252.wav...
# Processing SPEAKER_02_1252-1253.wav...
# Processing SPEAKER_02_1252-1252.wav...
# Processing SPEAKER_03_1254-1254.wav...
# Processing SPEAKER_02_1254-1254.wav...
# Processing SPEAKER_01_1254-1254.wav...
# Processing SPEAKER_03_1254-1260.wav...
# Processing SPEAKER_00_1254-1256.wav...
# Processing SPEAKER_02_1256-1256.wav...
# Processing SPEAKER_00_1261-1263.wav...
# Processing SPEAKER_00_1257-1259.wav...
# Processing SPEAKER_03_1262-1265.wav...
# Processing SPEAKER_00_1264-1265.wav...
# Processing SPEAKER_04_1265-1265.wav...
# Processing SPEAKER_00_1265-1265.wav...
# Processing SPEAKER_00_1265-1266.wav...
# Processing SPEAKER_01_1266-1269.wav...
# Processing SPEAKER_02_1268-1269.wav...
# Processing SPEAKER_00_1269-1269.wav...
# Processing SPEAKER_02_1269-1269.wav...
# Processing SPEAKER_02_1269-1271.wav...
# Processing SPEAKER_01_1269-1269.wav...
# Processing SPEAKER_02_1271-1271.wav...
# Processing SPEAKER_00_1271-1272.wav...
# Processing SPEAKER_00_1271-1271.wav...
# Processing SPEAKER_00_1272-1272.wav...
# Processing SPEAKER_02_1272-1273.wav...
# Processing SPEAKER_00_1273-1273.wav...
# Processing SPEAKER_02_1273-1273.wav...
# Processing SPEAKER_00_1276-1281.wav...
# Processing SPEAKER_00_1273-1276.wav...
# Processing SPEAKER_00_1280-1296.wav...
# Processing SPEAKER_01_1296-1300.wav...
# Processing SPEAKER_00_1306-1311.wav...
# Processing SPEAKER_00_1311-1313.wav...
# Processing SPEAKER_01_1311-1313.wav...
# Processing SPEAKER_01_1313-1317.wav...
# Processing SPEAKER_00_1317-1326.wav...
# Processing SPEAKER_01_1321-1325.wav...
# Processing SPEAKER_01_1318-1318.wav...
# Processing SPEAKER_02_1326-1326.wav...
# Processing SPEAKER_02_1327-1328.wav...
# Processing SPEAKER_01_1328-1328.wav...
# Processing SPEAKER_01_1328-1331.wav...
# Processing SPEAKER_00_1328-1333.wav...
# Processing SPEAKER_01_1333-1333.wav...
# Processing SPEAKER_02_1331-1333.wav...
# Processing SPEAKER_02_1334-1334.wav...
# Processing SPEAKER_00_1334-1334.wav...
# Processing SPEAKER_02_1336-1341.wav...
# Processing SPEAKER_00_1334-1335.wav...
# Processing SPEAKER_00_1340-1341.wav...
# Processing SPEAKER_02_1343-1345.wav...
# Processing SPEAKER_01_1345-1348.wav...
# Processing SPEAKER_01_1348-1354.wav...
# Processing SPEAKER_02_1346-1348.wav...
# Processing SPEAKER_02_1351-1351.wav...
# Processing SPEAKER_02_1348-1348.wav...
# Processing SPEAKER_02_1352-1352.wav...
# Processing SPEAKER_00_1351-1352.wav...
# Processing SPEAKER_00_1352-1352.wav...
# Processing SPEAKER_02_1353-1354.wav...
# Processing SPEAKER_02_1354-1354.wav...
# Processing SPEAKER_00_1354-1356.wav...
# Processing SPEAKER_01_1355-1355.wav...
# Processing SPEAKER_02_1355-1355.wav...
# Processing SPEAKER_03_1355-1355.wav...
# Processing SPEAKER_01_1356-1356.wav...
# Processing SPEAKER_00_1357-1357.wav...
# Processing SPEAKER_01_1356-1359.wav...
# Processing SPEAKER_00_1359-1360.wav...
# Processing SPEAKER_01_1359-1360.wav...
# Processing SPEAKER_01_1360-1361.wav...
# Processing SPEAKER_02_1360-1360.wav...
# Processing SPEAKER_00_1361-1368.wav...
# Processing SPEAKER_02_1360-1361.wav...
# Processing SPEAKER_02_1361-1362.wav...
# Processing SPEAKER_02_1365-1366.wav...
# Processing SPEAKER_02_1368-1368.wav...
# Processing SPEAKER_02_1368-1371.wav...
# Processing SPEAKER_02_1371-1374.wav...
# Processing SPEAKER_01_1373-1373.wav...
# Processing SPEAKER_02_1375-1377.wav...
# Processing SPEAKER_01_1374-1375.wav...
# Processing SPEAKER_01_1375-1378.wav...
# Processing SPEAKER_02_1379-1379.wav...
# Processing SPEAKER_02_1379-1381.wav...
# Processing SPEAKER_01_1379-1386.wav...
# Processing SPEAKER_01_1379-1379.wav...
# Processing SPEAKER_00_1381-1381.wav...
# Processing SPEAKER_00_1383-1383.wav...
# Processing SPEAKER_00_1386-1388.wav...
# Processing SPEAKER_00_1389-1389.wav...
# Processing SPEAKER_02_1388-1391.wav...
# Processing SPEAKER_01_1391-1393.wav...
# Processing SPEAKER_01_1394-1398.wav...
# Processing SPEAKER_02_1394-1395.wav...
# Processing SPEAKER_01_1398-1398.wav...
# Processing SPEAKER_03_1399-1401.wav...
# Processing SPEAKER_03_1398-1398.wav...
# Processing SPEAKER_01_1400-1401.wav...
# Processing SPEAKER_00_1401-1406.wav...
# Processing SPEAKER_02_1401-1402.wav...
# Processing SPEAKER_02_1402-1402.wav...
# Processing SPEAKER_02_1407-1409.wav...
# Processing SPEAKER_02_1406-1407.wav...
# Processing SPEAKER_01_1408-1408.wav...
# Processing SPEAKER_00_1409-1413.wav...
# Processing SPEAKER_02_1409-1411.wav...
# Processing SPEAKER_01_1411-1412.wav...
# Processing SPEAKER_02_1412-1412.wav...
# Processing SPEAKER_01_1412-1413.wav...
# Processing SPEAKER_02_1413-1414.wav...
# Processing SPEAKER_00_1413-1414.wav...
# Processing SPEAKER_01_1414-1414.wav...
# Processing SPEAKER_00_1414-1414.wav...
# Processing SPEAKER_01_1414-1415.wav...
# Processing SPEAKER_01_1415-1416.wav...
# Processing SPEAKER_02_1415-1416.wav...
# Processing SPEAKER_02_1416-1416.wav...
# Processing SPEAKER_02_1418-1423.wav...
# Processing SPEAKER_00_1418-1420.wav...
# Processing SPEAKER_00_1423-1424.wav...
# Processing SPEAKER_01_1423-1423.wav...
# Processing SPEAKER_02_1424-1424.wav...
# Processing SPEAKER_02_1424-1431.wav...
# Processing SPEAKER_00_1427-1431.wav...
# Processing SPEAKER_00_1424-1425.wav...
# Processing SPEAKER_01_1431-1434.wav...
# Processing SPEAKER_00_1434-1436.wav...
# Processing SPEAKER_00_1437-1446.wav...
# Processing SPEAKER_00_1446-1461.wav...
# Processing SPEAKER_00_1461-1463.wav...
# Processing SPEAKER_01_1474-1475.wav...
# Processing SPEAKER_00_1463-1472.wav...
# Processing SPEAKER_00_1476-1476.wav...
# Processing SPEAKER_02_1476-1479.wav...
# Processing SPEAKER_00_1489-1491.wav...
# Processing SPEAKER_01_1476-1491.wav...
# Processing SPEAKER_01_1495-1506.wav...
# Processing SPEAKER_00_1491-1493.wav...
# Transcriptions saved to /content/drive/MyDrive/2025AWS/FEniX_Text/transcriptions.json

# %%
#設置路徑準備將transcript切分speaker
# 輸入JSON檔案路徑
input_json_path = "/content/drive/MyDrive/2025AWS/FEniX_Text/transcriptions.json"
# 輸出資料夾路徑
output_folder = "/content/drive/MyDrive/2025AWS/FEniX_Text"

# 確保輸出資料夾存在
os.makedirs(output_folder, exist_ok=True)

# %%
#定義分割JSON的函數
def split_transcriptions_by_speaker(input_json_path, output_folder):
    """讀取transcriptions.json並按講者分割為單獨的JSON檔案"""
    try:
        # 讀取輸入JSON檔案
        with open(input_json_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        # 檢查JSON結構是否包含"SPEAKER"鍵
        if "SPEAKER" not in data:
            raise ValueError("JSON does not contain 'SPEAKER' key.")

        # 初始化字典來儲存按講者分類的轉錄
        transcriptions_by_speaker = {}

        # 遍歷"SPEAKER"中的每個條目
        for entry in data["SPEAKER"]:
            filename = entry.get("filename", "")
            if not filename or not filename.startswith("SPEAKER_"):
                print(f"Skipping invalid filename: {filename}")
                continue

            # 提取講者ID（例如 SPEAKER_00）
            speaker_id = filename.split("_")[0] + "_" + filename.split("_")[1]
            # 初始化講者ID的列表（如果尚未存在）
            if speaker_id not in transcriptions_by_speaker:
                transcriptions_by_speaker[speaker_id] = []

            # 添加轉錄條目到對應的講者
            transcriptions_by_speaker[speaker_id].append({
                "filename": filename,
                "text": entry.get("text", "")
            })

        # 為每個講者儲存JSON檔案
        for speaker_id, entries in transcriptions_by_speaker.items():
            output_json_path = os.path.join(output_folder, f"{speaker_id}.json")
            with open(output_json_path, "w", encoding="utf-8") as f:
                json.dump(entries, f, ensure_ascii=False, indent=4)
            print(f"Saved {speaker_id}.json to {output_folder}")

        print("All speaker JSON files have been created successfully!")

    except FileNotFoundError:
        print(f"Input file {input_json_path} not found. Please ensure it exists.")
    except json.JSONDecodeError:
        print(f"Error decoding {input_json_path}. Please check the JSON format.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
# 執行處理
if __name__ == "__main__":
    # 檢查輸入檔案是否存在
    if not os.path.exists(input_json_path):
        print(f"Input file {input_json_path} does not exist. Please check the path.")
    else:
        split_transcriptions_by_speaker(input_json_path, output_folder)
# Out:
# Saved SPEAKER_00.json to /content/drive/MyDrive/2025AWS/FEniX_Text
# Saved SPEAKER_01.json to /content/drive/MyDrive/2025AWS/FEniX_Text
# Saved SPEAKER_03.json to /content/drive/MyDrive/2025AWS/FEniX_Text
# Saved SPEAKER_02.json to /content/drive/MyDrive/2025AWS/FEniX_Text
# Saved SPEAKER_04.json to /content/drive/MyDrive/2025AWS/FEniX_Text
# All speaker JSON files have been created successfully!
